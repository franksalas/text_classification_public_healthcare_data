# %% [markdown]
# # Text cleanup
#
# -

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd

# %%
ls
# Out:
# contractions.py*                health03_text_cleanup.ipynb*
# health00_business.ipynb*        health04_sentiment_values.ipynb*
# health01_business.ipynb*        __pycache__/
# health02_business_merge.ipynb*  text_cleanup.py*
# health03_no.ipynb*              yelp_data/

# %%
path = 'yelp_data/health_raw00.csv'

df = pd.read_csv(path)
df.drop(['Unnamed: 0'],axis=1,inplace=True)

data = df[['stars','text']]
data = df.copy()

# %%
data.head()
# Out:
#               business_id                             categories  \
# 0  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 1  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 2  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 3  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 4  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
#
#                name state                                  categories_list  \
# 0  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 1  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 2  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 3  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 4  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
#
#    cool        date  funny               review_id  stars  \
# 0     0  2018-03-03      0  TNNkSmMfshsD3G60jTNjDA      1
# 1     0  2015-11-29      0  v-iKdstPdCxJr8zV1ZMdrw      5
# 2     0  2016-06-03      0  BmNDRCV9_NzQ_KCChyfdEw      4
# 3     0  2017-03-17      0  t_TKVMxKFYm9Hl-TIO7UUw      3
# 4     0  2016-08-31      0  NWRrpGRgWZBBj3lvCZGVKA      1
#
#                                                 text  useful  \
# 0  Please stay away from this place if you can! I...       2
# 1  My husband has been a patient of Dr. Byrne for...       1
# 2  Dr. Byrne is a great doctor! She has great bed...       2
# 3  I'm raising my review as Dr Bryne's has been m...       3
# 4  I wish I could give 0 stars. Worst office I've...       1
#
#                   user_id
# 0  xv2V2GO5IZYvtw4oW7gQ1w
# 1  SjvWP7c9toeZoV_q62zhTA
# 2  sZVHm1aLtvyH9trAc2_MgA
# 3  8Y_irXocZdZxLs_qgzpjBw
# 4  hVKPDGpG12z7vpScXaSakw

# %% [markdown]
# ## Text cleanup
#
# Functions for cleanup used from
# ### Practical Machine Learning with Python: A Problem-Solver's Guide to Building Real-World Intelligent Systems
# https://www.safaribooksonline.com/library/view/practical-machine-learning/9781484232071/

# %%
from text_cleanup import normalize_corpus

# %% [markdown]
# ## Test cleanup

# %%
test = data.loc[:20]

# %%
test
# Out:
#                business_id                                         categories  \
# 0   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 1   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 2   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 3   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 4   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 5   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 6   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 7   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 8   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 9   STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 10  STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 11  STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 12  STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 13  STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 14  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 15  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 16  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 17  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 18  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 19  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 20  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
#
#                                    name state  \
# 0                      Lauren Byrne, MD    AZ
# 1                      Lauren Byrne, MD    AZ
# 2                      Lauren Byrne, MD    AZ
# 3                      Lauren Byrne, MD    AZ
# 4                      Lauren Byrne, MD    AZ
# 5                      Lauren Byrne, MD    AZ
# 6                      Lauren Byrne, MD    AZ
# 7                      Lauren Byrne, MD    AZ
# 8                      Lauren Byrne, MD    AZ
# 9           Black Mountain Orthopaedics    NV
# 10          Black Mountain Orthopaedics    NV
# 11          Black Mountain Orthopaedics    NV
# 12          Black Mountain Orthopaedics    NV
# 13          Black Mountain Orthopaedics    NV
# 14  Central Phoenix Women's Health Care    AZ
# 15  Central Phoenix Women's Health Care    AZ
# 16  Central Phoenix Women's Health Care    AZ
# 17  Central Phoenix Women's Health Care    AZ
# 18  Central Phoenix Women's Health Care    AZ
# 19  Central Phoenix Women's Health Care    AZ
# 20  Central Phoenix Women's Health Care    AZ
#
#                                       categories_list  cool        date  \
# 0     ['urologists', ' doctors', ' health & medical']     0  2018-03-03
# 1     ['urologists', ' doctors', ' health & medical']     0  2015-11-29
# 2     ['urologists', ' doctors', ' health & medical']     0  2016-06-03
# 3     ['urologists', ' doctors', ' health & medical']     0  2017-03-17
# 4     ['urologists', ' doctors', ' health & medical']     0  2016-08-31
# 5     ['urologists', ' doctors', ' health & medical']     0  2018-05-06
# 6     ['urologists', ' doctors', ' health & medical']     0  2017-10-16
# 7     ['urologists', ' doctors', ' health & medical']     0  2017-08-10
# 8     ['urologists', ' doctors', ' health & medical']     0  2017-01-23
# 9   ['doctors', ' orthopedists', ' health & medical']     1  2012-03-06
# 10  ['doctors', ' orthopedists', ' health & medical']     0  2014-04-23
# 11  ['doctors', ' orthopedists', ' health & medical']     1  2013-04-28
# 12  ['doctors', ' orthopedists', ' health & medical']     0  2013-06-13
# 13  ['doctors', ' orthopedists', ' health & medical']     0  2011-07-06
# 14  ['obstetricians & gynecologists', ' health & m...     0  2016-04-18
# 15  ['obstetricians & gynecologists', ' health & m...     0  2015-06-17
# 16  ['obstetricians & gynecologists', ' health & m...     0  2012-03-14
# 17  ['obstetricians & gynecologists', ' health & m...     1  2013-02-27
# 18  ['obstetricians & gynecologists', ' health & m...     1  2015-09-23
# 19  ['obstetricians & gynecologists', ' health & m...     0  2016-12-13
# 20  ['obstetricians & gynecologists', ' health & m...     0  2017-02-07
#
#     funny               review_id  stars  \
# 0       0  TNNkSmMfshsD3G60jTNjDA      1
# 1       0  v-iKdstPdCxJr8zV1ZMdrw      5
# 2       0  BmNDRCV9_NzQ_KCChyfdEw      4
# 3       0  t_TKVMxKFYm9Hl-TIO7UUw      3
# 4       0  NWRrpGRgWZBBj3lvCZGVKA      1
# 5       0  jX47gPdL1ta_OTt5HgDSGQ      1
# 6       0  LSCLa-SIOgaOxP4r3VjX-A      5
# 7       0  O78Aq4xO8WsdISZMLJWOtQ      1
# 8       0  B3ie19nC7VGj3GL6-aO3nA      1
# 9       0  Ap0anyQxUx8OijF_CjRJyA      5
# 10      0  0fa2B5haSpPAtHvZSHI0Rw      2
# 11      0  f9tOerROlkuu_C2h636zVA      5
# 12      0  xfqgeZRawj5CNPyAXeYx_Q      1
# 13      0  R16Hzb1PchRulqVEyJWrvQ      5
# 14      1  4XzI7RF60_HYjloGSbkuGg      5
# 15      0  NSZyJuaWSSWS7dGcOrLCpQ      5
# 16      0  4XECtyxtvBJhbElJHaL6-A      1
# 17      4  b_dPL8jdRkPS4cWWWnzMUg      2
# 18      0  Hmq1J83qB9K8LtCXXWB9ag      1
# 19      0  sb62a6R1WcFGRJTkLT26SA      5
# 20      1  ri1escRr9-siSye3fkCDRQ      5
#
#                                                  text  useful  \
# 0   Please stay away from this place if you can! I...       2
# 1   My husband has been a patient of Dr. Byrne for...       1
# 2   Dr. Byrne is a great doctor! She has great bed...       2
# 3   I'm raising my review as Dr Bryne's has been m...       3
# 4   I wish I could give 0 stars. Worst office I've...       1
# 5   I went to the emergency room because i was hav...       1
# 6   Dr. Byrne is an excellent doctor with all the ...       3
# 7   Worst place ever. Dr Bryne had to reschedule m...       0
# 8   Update to my last review.  My situation got ev...       2
# 9   I'm going to follow Jacie's example and give y...       1
# 10  I normally dont write review but this time im ...       2
# 11  dr. mario quesada both of my arthroscopic knee...       1
# 12  Waited over an hour after my scheduled appoint...       1
# 13  Love Dr. Ravitch. He has the best knowledge an...       0
# 14  I moved to the area at about 25 weeks pregnant...       2
# 15  People need to get over it! This isn't the 195...       0
# 16  This place is a joke.\n\nI work in customer se...       3
# 17  The only reason I'm giving this place two star...       8
# 18  I'm sure Dr. Hahn is great at handling healthy...      11
# 19  Dr. Cyr was awesome! This place was great from...       3
# 20  I have been a patient of this group for over 1...       1
#
#                    user_id
# 0   xv2V2GO5IZYvtw4oW7gQ1w
# 1   SjvWP7c9toeZoV_q62zhTA
# 2   sZVHm1aLtvyH9trAc2_MgA
# 3   8Y_irXocZdZxLs_qgzpjBw
# 4   hVKPDGpG12z7vpScXaSakw
# 5   KZ2_AsAYr3iSsUfK06W-aw
# 6   OrsSCQlWIOiitqDSzwn4bQ
# 7   FvMiqD6kciJq6um3yFlkZQ
# 8   L3nYsxpkshtU_xdNh3mM1Q
# 9   MAzrWB0y2O0lfSBalPu0Iw
# 10  gaecjcW_7Y9mui_Nj_67pQ
# 11  klN7Yw_aVUBscqhlkpKkRA
# 12  vf0qKqUiTsyznFvKu2PqGQ
# 13  KQqDOlCMgVbdfLWUpFjQeg
# 14  G8zXwB63B79H1pgHOh59Kg
# 15  Oq1Rx0LtXYYFUdcstYaNNw
# 16  KlAkPapgrjPo-wX5egVgDQ
# 17  YKx4wqrFxNS1TexLQ9HB7Q
# 18  PPL50QJOvn5uSUqQ55ortg
# 19  Hc-pOjlJOLlaWnMWz-ymVw
# 20  xabJHjqFXuoJfD97frdZcg

# %%
# %%time
test['clean_text'] = normalize_corpus(test['text'])
# Out:
# CPU times: user 13.6 s, sys: 1.72 s, total: 15.3 s
# Wall time: 2.04 s

# %%
test
# Out:
#                business_id                                         categories  \
# 0   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 1   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 2   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 3   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 4   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 5   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 6   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 7   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 8   y-4xTZNKVm8mAZpiXMS5ZA              urologists, doctors, health & medical
# 9   STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 10  STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 11  STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 12  STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 13  STcSSjPOZ0FWtjvjqw99Dg            doctors, orthopedists, health & medical
# 14  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 15  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 16  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 17  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 18  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 19  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
# 20  WnRtn80rdsWOa2nWZ6G1iA  obstetricians & gynecologists, health & medica...
#
#                                    name state  \
# 0                      Lauren Byrne, MD    AZ
# 1                      Lauren Byrne, MD    AZ
# 2                      Lauren Byrne, MD    AZ
# 3                      Lauren Byrne, MD    AZ
# 4                      Lauren Byrne, MD    AZ
# 5                      Lauren Byrne, MD    AZ
# 6                      Lauren Byrne, MD    AZ
# 7                      Lauren Byrne, MD    AZ
# 8                      Lauren Byrne, MD    AZ
# 9           Black Mountain Orthopaedics    NV
# 10          Black Mountain Orthopaedics    NV
# 11          Black Mountain Orthopaedics    NV
# 12          Black Mountain Orthopaedics    NV
# 13          Black Mountain Orthopaedics    NV
# 14  Central Phoenix Women's Health Care    AZ
# 15  Central Phoenix Women's Health Care    AZ
# 16  Central Phoenix Women's Health Care    AZ
# 17  Central Phoenix Women's Health Care    AZ
# 18  Central Phoenix Women's Health Care    AZ
# 19  Central Phoenix Women's Health Care    AZ
# 20  Central Phoenix Women's Health Care    AZ
#
#                                       categories_list  cool        date  \
# 0     ['urologists', ' doctors', ' health & medical']     0  2018-03-03
# 1     ['urologists', ' doctors', ' health & medical']     0  2015-11-29
# 2     ['urologists', ' doctors', ' health & medical']     0  2016-06-03
# 3     ['urologists', ' doctors', ' health & medical']     0  2017-03-17
# 4     ['urologists', ' doctors', ' health & medical']     0  2016-08-31
# 5     ['urologists', ' doctors', ' health & medical']     0  2018-05-06
# 6     ['urologists', ' doctors', ' health & medical']     0  2017-10-16
# 7     ['urologists', ' doctors', ' health & medical']     0  2017-08-10
# 8     ['urologists', ' doctors', ' health & medical']     0  2017-01-23
# 9   ['doctors', ' orthopedists', ' health & medical']     1  2012-03-06
# 10  ['doctors', ' orthopedists', ' health & medical']     0  2014-04-23
# 11  ['doctors', ' orthopedists', ' health & medical']     1  2013-04-28
# 12  ['doctors', ' orthopedists', ' health & medical']     0  2013-06-13
# 13  ['doctors', ' orthopedists', ' health & medical']     0  2011-07-06
# 14  ['obstetricians & gynecologists', ' health & m...     0  2016-04-18
# 15  ['obstetricians & gynecologists', ' health & m...     0  2015-06-17
# 16  ['obstetricians & gynecologists', ' health & m...     0  2012-03-14
# 17  ['obstetricians & gynecologists', ' health & m...     1  2013-02-27
# 18  ['obstetricians & gynecologists', ' health & m...     1  2015-09-23
# 19  ['obstetricians & gynecologists', ' health & m...     0  2016-12-13
# 20  ['obstetricians & gynecologists', ' health & m...     0  2017-02-07
#
#     funny               review_id  stars  \
# 0       0  TNNkSmMfshsD3G60jTNjDA      1
# 1       0  v-iKdstPdCxJr8zV1ZMdrw      5
# 2       0  BmNDRCV9_NzQ_KCChyfdEw      4
# 3       0  t_TKVMxKFYm9Hl-TIO7UUw      3
# 4       0  NWRrpGRgWZBBj3lvCZGVKA      1
# 5       0  jX47gPdL1ta_OTt5HgDSGQ      1
# 6       0  LSCLa-SIOgaOxP4r3VjX-A      5
# 7       0  O78Aq4xO8WsdISZMLJWOtQ      1
# 8       0  B3ie19nC7VGj3GL6-aO3nA      1
# 9       0  Ap0anyQxUx8OijF_CjRJyA      5
# 10      0  0fa2B5haSpPAtHvZSHI0Rw      2
# 11      0  f9tOerROlkuu_C2h636zVA      5
# 12      0  xfqgeZRawj5CNPyAXeYx_Q      1
# 13      0  R16Hzb1PchRulqVEyJWrvQ      5
# 14      1  4XzI7RF60_HYjloGSbkuGg      5
# 15      0  NSZyJuaWSSWS7dGcOrLCpQ      5
# 16      0  4XECtyxtvBJhbElJHaL6-A      1
# 17      4  b_dPL8jdRkPS4cWWWnzMUg      2
# 18      0  Hmq1J83qB9K8LtCXXWB9ag      1
# 19      0  sb62a6R1WcFGRJTkLT26SA      5
# 20      1  ri1escRr9-siSye3fkCDRQ      5
#
#                                                  text  useful  \
# 0   Please stay away from this place if you can! I...       2
# 1   My husband has been a patient of Dr. Byrne for...       1
# 2   Dr. Byrne is a great doctor! She has great bed...       2
# 3   I'm raising my review as Dr Bryne's has been m...       3
# 4   I wish I could give 0 stars. Worst office I've...       1
# 5   I went to the emergency room because i was hav...       1
# 6   Dr. Byrne is an excellent doctor with all the ...       3
# 7   Worst place ever. Dr Bryne had to reschedule m...       0
# 8   Update to my last review.  My situation got ev...       2
# 9   I'm going to follow Jacie's example and give y...       1
# 10  I normally dont write review but this time im ...       2
# 11  dr. mario quesada both of my arthroscopic knee...       1
# 12  Waited over an hour after my scheduled appoint...       1
# 13  Love Dr. Ravitch. He has the best knowledge an...       0
# 14  I moved to the area at about 25 weeks pregnant...       2
# 15  People need to get over it! This isn't the 195...       0
# 16  This place is a joke.\n\nI work in customer se...       3
# 17  The only reason I'm giving this place two star...       8
# 18  I'm sure Dr. Hahn is great at handling healthy...      11
# 19  Dr. Cyr was awesome! This place was great from...       3
# 20  I have been a patient of this group for over 1...       1
#
#                    user_id                                         clean_text
# 0   xv2V2GO5IZYvtw4oW7gQ1w  please stay away place bad care imaginable sta...
# 1   SjvWP7c9toeZoV_q62zhTA  husband patient dr byrne last year half last m...
# 2   sZVHm1aLtvyH9trAc2_MgA  dr byrne great doctor great bed side manner ex...
# 3   8Y_irXocZdZxLs_qgzpjBw  raise review dr bryne receptive daughter go an...
# 4   hVKPDGpG12z7vpScXaSakw  wish could give star bad office ever horrible ...
# 5   KZ2_AsAYr3iSsUfK06W-aw  go emergency room kidney stone attack emergenc...
# 6   OrsSCQlWIOiitqDSzwn4bQ  dr byrne excellent doctor right skill include ...
# 7   FvMiqD6kciJq6um3yFlkZQ  bad place ever dr bryne reschedule first appt ...
# 8   L3nYsxpkshtU_xdNh3mM1Q  update last review situation get even bad urin...
# 9   MAzrWB0y2O0lfSBalPu0Iw  go follow jacie example give run whole story f...
# 10  gaecjcW_7Y9mui_Nj_67pQ  normally not write review time upset past wait...
# 11  klN7Yw_aVUBscqhlkpKkRA  dr mario quesada arthroscopic knee surgery dr ...
# 12  vf0qKqUiTsyznFvKu2PqGQ  wait hour schedule appointment time first appo...
# 13  KQqDOlCMgVbdfLWUpFjQeg  love dr ravitch good knowledge awesome demeano...
# 14  G8zXwB63B79H1pgHOh59Kg  move area week pregnant start look new ob righ...
# 15  Oq1Rx0LtXYYFUdcstYaNNw  people need get not anymore drs not come house...
# 16  KlAkPapgrjPo-wX5egVgDQ  place joke work customer service often time tr...
# 17  YKx4wqrFxNS1TexLQ9HB7Q  reason give place two star instead one star re...
# 18  PPL50QJOvn5uSUqQ55ortg  sure dr hahn great handle healthy pregnancy co...
# 19  Hc-pOjlJOLlaWnMWz-ymVw  dr cyr awesome place great front staff billing...
# 20  xabJHjqFXuoJfD97frdZcg  patient group year viable pregnancy loss staff...

# %% [markdown]
# ## Now Lets do it for the entire dataset
#
# ## Time
#
# ```
# CPU times: user 5h 49min 44s, sys: 38min 29s, total: 6h 28min 14s
# Wall time: 48min 35s
# ```

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64006 entries, 0 to 64005
# Data columns (total 13 columns):
# business_id        64006 non-null object
# categories         64006 non-null object
# name               64006 non-null object
# state              64006 non-null object
# categories_list    64006 non-null object
# cool               64006 non-null int64
# date               64006 non-null object
# funny              64006 non-null int64
# review_id          64006 non-null object
# stars              64006 non-null int64
# text               64006 non-null object
# useful             64006 non-null int64
# user_id            64006 non-null object
# dtypes: int64(4), object(9)
# memory usage: 6.3+ MB

# %%
data.head()
# Out:
#               business_id                             categories  \
# 0  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 1  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 2  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 3  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 4  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
#
#                name state                                  categories_list  \
# 0  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 1  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 2  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 3  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 4  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
#
#    cool        date  funny               review_id  stars  \
# 0     0  2018-03-03      0  TNNkSmMfshsD3G60jTNjDA      1
# 1     0  2015-11-29      0  v-iKdstPdCxJr8zV1ZMdrw      5
# 2     0  2016-06-03      0  BmNDRCV9_NzQ_KCChyfdEw      4
# 3     0  2017-03-17      0  t_TKVMxKFYm9Hl-TIO7UUw      3
# 4     0  2016-08-31      0  NWRrpGRgWZBBj3lvCZGVKA      1
#
#                                                 text  useful  \
# 0  Please stay away from this place if you can! I...       2
# 1  My husband has been a patient of Dr. Byrne for...       1
# 2  Dr. Byrne is a great doctor! She has great bed...       2
# 3  I'm raising my review as Dr Bryne's has been m...       3
# 4  I wish I could give 0 stars. Worst office I've...       1
#
#                   user_id
# 0  xv2V2GO5IZYvtw4oW7gQ1w
# 1  SjvWP7c9toeZoV_q62zhTA
# 2  sZVHm1aLtvyH9trAc2_MgA
# 3  8Y_irXocZdZxLs_qgzpjBw
# 4  hVKPDGpG12z7vpScXaSakw

# %%
# %%time
data['clean_text'] = normalize_corpus(data['text'])
# Out:
# CPU times: user 6h 1min 28s, sys: 38min 54s, total: 6h 40min 22s
# Wall time: 50min 6s

# %%
data.head()
# Out:
#               business_id                             categories  \
# 0  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 1  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 2  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 3  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
# 4  y-4xTZNKVm8mAZpiXMS5ZA  urologists, doctors, health & medical
#
#                name state                                  categories_list  \
# 0  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 1  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 2  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 3  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
# 4  Lauren Byrne, MD    AZ  ['urologists', ' doctors', ' health & medical']
#
#    cool        date  funny               review_id  stars  \
# 0     0  2018-03-03      0  TNNkSmMfshsD3G60jTNjDA      1
# 1     0  2015-11-29      0  v-iKdstPdCxJr8zV1ZMdrw      5
# 2     0  2016-06-03      0  BmNDRCV9_NzQ_KCChyfdEw      4
# 3     0  2017-03-17      0  t_TKVMxKFYm9Hl-TIO7UUw      3
# 4     0  2016-08-31      0  NWRrpGRgWZBBj3lvCZGVKA      1
#
#                                                 text  useful  \
# 0  Please stay away from this place if you can! I...       2
# 1  My husband has been a patient of Dr. Byrne for...       1
# 2  Dr. Byrne is a great doctor! She has great bed...       2
# 3  I'm raising my review as Dr Bryne's has been m...       3
# 4  I wish I could give 0 stars. Worst office I've...       1
#
#                   user_id                                         clean_text
# 0  xv2V2GO5IZYvtw4oW7gQ1w  please stay away place bad care imaginable sta...
# 1  SjvWP7c9toeZoV_q62zhTA  husband patient dr byrne last year half last m...
# 2  sZVHm1aLtvyH9trAc2_MgA  dr byrne great doctor great bed side manner ex...
# 3  8Y_irXocZdZxLs_qgzpjBw  raise review dr bryne receptive daughter go an...
# 4  hVKPDGpG12z7vpScXaSakw  wish could give star bad office ever horrible ...

# %% [markdown]
# ## Review
#
# - cleaned up text
#
# ## Save

# %%
path = 'yelp_data/health_text_full.csv'

data.to_csv(path)
