# %% [markdown]
# # Text cleanup
#
# -

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd

# %%
ls
# Out:
# contractions.py*     health03_YES.ipynb*  health07_YES.ipynb*  text_cleanup.py*
# health00_YES.ipynb*  health04_YES.ipynb*  health08_YES.ipynb*  Untitled.ipynb*
# health01_YES.ipynb*  health05_YES.ipynb*  health09_YES.ipynb*  yelp_data/
# health02_YES.ipynb*  health06_YES.ipynb*  __pycache__/

# %%
path = 'yelp_data/health_raw00.csv'

df = pd.read_csv(path)
df.drop(['Unnamed: 0'],axis=1,inplace=True)

data = df[['stars','text']]

# %%
data.head()
# Out:
#    stars                                               text
# 0      1  Please stay away from this place if you can! I...
# 1      5  My husband has been a patient of Dr. Byrne for...
# 2      4  Dr. Byrne is a great doctor! She has great bed...
# 3      3  I'm raising my review as Dr Bryne's has been m...
# 4      1  I wish I could give 0 stars. Worst office I've...

# %% [markdown]
# ## Text cleanup
#
# Functions for cleanup used from
# ### Practical Machine Learning with Python: A Problem-Solver's Guide to Building Real-World Intelligent Systems
# https://www.safaribooksonline.com/library/view/practical-machine-learning/9781484232071/

# %%
from text_cleanup import normalize_corpus

# %% [markdown]
# ## Test cleanup

# %%
test = data.loc[:20]

# %%
test
# Out:
#     stars                                               text
# 0       1  Please stay away from this place if you can! I...
# 1       5  My husband has been a patient of Dr. Byrne for...
# 2       4  Dr. Byrne is a great doctor! She has great bed...
# 3       3  I'm raising my review as Dr Bryne's has been m...
# 4       1  I wish I could give 0 stars. Worst office I've...
# 5       1  I went to the emergency room because i was hav...
# 6       5  Dr. Byrne is an excellent doctor with all the ...
# 7       1  Worst place ever. Dr Bryne had to reschedule m...
# 8       1  Update to my last review.  My situation got ev...
# 9       5  I'm going to follow Jacie's example and give y...
# 10      2  I normally dont write review but this time im ...
# 11      5  dr. mario quesada both of my arthroscopic knee...
# 12      1  Waited over an hour after my scheduled appoint...
# 13      5  Love Dr. Ravitch. He has the best knowledge an...
# 14      5  I moved to the area at about 25 weeks pregnant...
# 15      5  People need to get over it! This isn't the 195...
# 16      1  This place is a joke.\n\nI work in customer se...
# 17      2  The only reason I'm giving this place two star...
# 18      1  I'm sure Dr. Hahn is great at handling healthy...
# 19      5  Dr. Cyr was awesome! This place was great from...
# 20      5  I have been a patient of this group for over 1...

# %%
# %%time
test['clean_text'] = normalize_corpus(test['text'])
# Out:
# CPU times: user 11.9 s, sys: 1.83 s, total: 13.7 s
# Wall time: 1.84 s

# %%
test
# Out:
#     stars                                               text  \
# 0       1  Please stay away from this place if you can! I...
# 1       5  My husband has been a patient of Dr. Byrne for...
# 2       4  Dr. Byrne is a great doctor! She has great bed...
# 3       3  I'm raising my review as Dr Bryne's has been m...
# 4       1  I wish I could give 0 stars. Worst office I've...
# 5       1  I went to the emergency room because i was hav...
# 6       5  Dr. Byrne is an excellent doctor with all the ...
# 7       1  Worst place ever. Dr Bryne had to reschedule m...
# 8       1  Update to my last review.  My situation got ev...
# 9       5  I'm going to follow Jacie's example and give y...
# 10      2  I normally dont write review but this time im ...
# 11      5  dr. mario quesada both of my arthroscopic knee...
# 12      1  Waited over an hour after my scheduled appoint...
# 13      5  Love Dr. Ravitch. He has the best knowledge an...
# 14      5  I moved to the area at about 25 weeks pregnant...
# 15      5  People need to get over it! This isn't the 195...
# 16      1  This place is a joke.\n\nI work in customer se...
# 17      2  The only reason I'm giving this place two star...
# 18      1  I'm sure Dr. Hahn is great at handling healthy...
# 19      5  Dr. Cyr was awesome! This place was great from...
# 20      5  I have been a patient of this group for over 1...
#
#                                            clean_text
# 0   please stay away place bad care imaginable sta...
# 1   husband patient dr byrne last year half last m...
# 2   dr byrne great doctor great bed side manner ex...
# 3   raise review dr bryne receptive daughter go an...
# 4   wish could give star bad office ever horrible ...
# 5   go emergency room kidney stone attack emergenc...
# 6   dr byrne excellent doctor right skill include ...
# 7   bad place ever dr bryne reschedule first appt ...
# 8   update last review situation get even bad urin...
# 9   go follow jacie example give run whole story f...
# 10  normally not write review time upset past wait...
# 11  dr mario quesada arthroscopic knee surgery dr ...
# 12  wait hour schedule appointment time first appo...
# 13  love dr ravitch good knowledge awesome demeano...
# 14  move area week pregnant start look new ob righ...
# 15  people need get not anymore drs not come house...
# 16  place joke work customer service often time tr...
# 17  reason give place two star instead one star re...
# 18  sure dr hahn great handle healthy pregnancy co...
# 19  dr cyr awesome place great front staff billing...
# 20  patient group year viable pregnancy loss staff...

# %% [markdown]
# ## Now Lets do it for the entire dataset
#
# ## Time
#
# ```
# CPU times: user 5h 49min 44s, sys: 38min 29s, total: 6h 28min 14s
# Wall time: 48min 35s
# ```

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64006 entries, 0 to 64005
# Data columns (total 2 columns):
# stars    64006 non-null int64
# text     64006 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1000.2+ KB

# %%
data.head()
# Out:
#    stars                                               text
# 0      1  Please stay away from this place if you can! I...
# 1      5  My husband has been a patient of Dr. Byrne for...
# 2      4  Dr. Byrne is a great doctor! She has great bed...
# 3      3  I'm raising my review as Dr Bryne's has been m...
# 4      1  I wish I could give 0 stars. Worst office I've...

# %%
# %%time
data['clean_text'] = normalize_corpus(data['text'])
# Out:
# CPU times: user 5h 49min 44s, sys: 38min 29s, total: 6h 28min 14s
# Wall time: 48min 35s

# %%
data.head()
# Out:
#    stars                                               text  \
# 0      1  Please stay away from this place if you can! I...
# 1      5  My husband has been a patient of Dr. Byrne for...
# 2      4  Dr. Byrne is a great doctor! She has great bed...
# 3      3  I'm raising my review as Dr Bryne's has been m...
# 4      1  I wish I could give 0 stars. Worst office I've...
#
#                                           clean_text
# 0  please stay away place bad care imaginable sta...
# 1  husband patient dr byrne last year half last m...
# 2  dr byrne great doctor great bed side manner ex...
# 3  raise review dr bryne receptive daughter go an...
# 4  wish could give star bad office ever horrible ...

# %% [markdown]
# ## Review
#
# - cleaned up text
#
# ## Save

# %%
path = 'yelp_data/health_text.csv'

data.to_csv(path)
